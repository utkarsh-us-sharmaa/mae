# %%
import matlab.engine
import numpy as np
import pandas as pd
import os
import time
import shutil


base_dir = '/Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/'
temp_output_dir = base_dir
csv_output_dir = os.path.join(base_dir, 'datasets_complex')
os.makedirs(csv_output_dir, exist_ok=True)

# %%
def scale_to_bounds(y_values, min_val, max_val):
    """
    Scale the y-values to ensure they stay within physical bounds while preserving pattern.
    
    Parameters:
    -----------
    y_values : numpy.ndarray
        Array of y-values to scale
    min_val : float
        Minimum allowed value
    max_val : float
        Maximum allowed value
    
    Returns:
    --------
    numpy.ndarray
        Scaled y-values within the specified bounds
    """
   
    y_norm = (y_values - np.min(y_values)) / (np.max(y_values) - np.min(y_values))
    
    
    y_scaled = y_norm * (max_val - min_val) + min_val
    
    return y_scaled


def generate_quadratic_equations(intercept, y_end, num_equations, start_id):
    """
    Generate quadratic thermal conductivity profiles.
    The quadratic equations are carefully crafted to ensure:
    1. They start at the specified intercept
    2. Stay within physical bounds
    3. Create meaningful thermal conductivity patterns
    """

    x_values = np.linspace(80, 400, 100)
    

    data = []
    equation_id = start_id
    
    for _ in range(num_equations):
       
        a = np.random.uniform(-0.0001, 0.0001)
        
        
        x_end = 400
        b = (y_end - a*x_end**2 - intercept) / x_end
        
        
        y_values = a * x_values**2 + b * x_values + intercept
        
     
        equation = f"y = {a:.6f}x² + {b:.4f}x + {intercept:.2f}"
        
     
        if all(y_values > 0):
            for x, y in zip(x_values, y_values):
                data.append([
                    equation,
                    'quadratic',
                    equation_id,
                    x,
                    y
                ])
            equation_id += 1
    
    # Create DataFrame
    df = pd.DataFrame(data, columns=[
        "Equations",
        "Equation Type",
        "Equation ID",
        "x (Thickness)",
        "y (Thermal Conductivity Profile)"
    ])
    
    return df

# %%
# Process output file function
def process_output_file(output_file):
    """Process MATLAB output files"""
    print(f"Reading file: {output_file}")
    with open(output_file, 'r') as file:
        lines = file.readlines()
        print(f"Number of lines in file: {len(lines)}")
        data = [line.strip().split() for line in lines if line.strip()]
        filtered_data = [row for row in data if len(row) >= 2]
        if filtered_data:
            print(f"Sample data point: {filtered_data[0]}")
    return [float(row[0]) for row in filtered_data], [float(row[-1]) for row in filtered_data]

# %%
# Main processing function
def process_equations(start_id, end_id, intercept, y_end):
    """
    Process quadratic equations through MATLAB.
    Now simplified to work with the 9-layer structure directly.
    """
    print(f"\nStarting process for equations {start_id} to {end_id}")
    
    # Generate quadratic equations
    df = generate_quadratic_equations(
        intercept=intercept,
        y_end=y_end,
        num_equations=100,
        start_id=start_id
    )
    print(f"Generated DataFrame shape: {df.shape}")
    
    # Process each equation
    results = []
    for equation_id in df['Equation ID'].unique():
        profile = df[df['Equation ID'] == equation_id]['y (Thermal Conductivity Profile)'].tolist()
        
        # Create 9-layer structure for MATLAB
        # Sample 5 evenly spaced points from the profile for the middle layers
        indices = np.linspace(0, len(profile)-1, 5, dtype=int)
        five_layers = [profile[i] for i in indices]
        
        lambda_array = [
            140,            # Al surface
            0.06,          # First interface
            five_layers[0], # Layer 1
            five_layers[1], # Layer 2
            five_layers[2], # Layer 3
            five_layers[3], # Layer 4
            five_layers[4], # Layer 5
            0.1,           # Second interface
            140            # Substrate
        ]
        
        try:
            file_name = f'Equation_{equation_id}'
            
            # Process through MATLAB
            eng = matlab.engine.start_matlab()
            eng.TDTR_MAIN_V4(matlab.double(lambda_array), file_name, nargout=0)
            eng.quit()
            
            # Process results
            output_file = os.path.join(base_dir, f"{file_name}.txt")
            if os.path.exists(output_file):
                first_column, last_column = process_output_file(output_file)
                
                # Store results
                for tdelay, model_ratio in zip(first_column, last_column):
                    original_rows = df[df['Equation ID'] == equation_id]
                    for _, row in original_rows.iterrows():
                        results.append({
                            'Equations': row['Equations'],
                            'Equation Type': row['Equation Type'],
                            'Equation ID': equation_id,
                            'x (Thickness)': row['x (Thickness)'],
                            'y (Thermal Conductivity Profile)': row['y (Thermal Conductivity Profile)'],
                            'Tdelay': tdelay,
                            'ModelRatio': model_ratio
                        })
                
                os.remove(output_file)
            
        except Exception as e:
            print(f"Error processing {file_name}: {e}")
            continue
    
    # Create final DataFrame
    final_df = pd.DataFrame(results)
    
    # Save to CSV
    csv_filename = f'Dataset_{start_id}_{end_id}.csv'
    csv_path = os.path.join(csv_output_dir, csv_filename)
    final_df.to_csv(csv_path, index=False)
    
    return final_df

# %%
# Main execution
start_id = 4034

parameter_sets = [
    (9.2, 9.4),    # Like silver
    (8.8, 9.0),    # Transition range
    (7.6, 7.8),    # Between aluminum and copper ranges
    (7.2, 7.4),    # High-end alloy range
    (5.8, 6.0),    # Like bronze
    (5.4, 5.6),    # Medium-high transition
    (2.6, 2.8),    # Like boron nitride
    (2.2, 2.4),    # Like magnesia
    (0.8, 1.0),    # Like some ceramics
    (0.4, 0.6)     # Like some polymers
]

# Generate equations for each parameter set
for batch in range(10):
    batch_start = start_id + (batch * 100)
    batch_end = batch_start + 100
    
    intercept, y_end = parameter_sets[batch]
    
    print(f"\nProcessing Batch {batch + 1}/10")
    print(f"IDs: {batch_start} to {batch_end}")
    print(f"Intercept: {intercept} (W/mK), y_end: {y_end} (W/mK)")
    
    df = process_equations(
        start_id=batch_start,
        end_id=batch_end,
        intercept=intercept,
        y_end=y_end
    )
# Out:
# Processing Batch 1/10
# IDs: 4034 to 4134
# Intercept: 9.2 (W/mK), y_end: 9.4 (W/mK)
#
# Starting process for equations 4034 to 4134
# Generated DataFrame shape: (10000, 5)
# Fitting Solution:
# Output file saved as: Equation_4034.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4034.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001268', '-0.000416', '3.045946']
# Fitting Solution:
# Output file saved as: Equation_4035.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4035.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001337', '-0.000564', '2.368886']
# Fitting Solution:
# Output file saved as: Equation_4036.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4036.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001310', '-0.000494', '2.648877']
# Fitting Solution:
# Output file saved as: Equation_4037.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4037.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001310', '-0.000495', '2.644986']
# Fitting Solution:
# Output file saved as: Equation_4038.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4038.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001287', '-0.000450', '2.863375']
# Fitting Solution:
# Output file saved as: Equation_4039.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4039.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001274', '-0.000426', '2.987245']
# Fitting Solution:
# Output file saved as: Equation_4040.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4040.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001330', '-0.000545', '2.441095']
# Fitting Solution:
# Output file saved as: Equation_4041.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4041.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001323', '-0.000525', '2.517630']
# Fitting Solution:
# Output file saved as: Equation_4042.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4042.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001281', '-0.000438', '2.925517']
# Fitting Solution:
# Output file saved as: Equation_4043.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4043.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001270', '-0.000420', '3.026186']
# Fitting Solution:
# Output file saved as: Equation_4044.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4044.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001304', '-0.000483', '2.698869']
# Fitting Solution:
# Output file saved as: Equation_4045.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4045.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001277', '-0.000431', '2.962104']
# Fitting Solution:
# Output file saved as: Equation_4046.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4046.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001274', '-0.000427', '2.984135']
# Fitting Solution:
# Output file saved as: Equation_4047.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4047.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001299', '-0.000472', '2.752686']
# Fitting Solution:
# Output file saved as: Equation_4048.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4048.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001283', '-0.000442', '2.901326']
# Fitting Solution:
# Output file saved as: Equation_4049.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4049.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001273', '-0.000425', '2.995316']
# Fitting Solution:
# Output file saved as: Equation_4050.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4050.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001279', '-0.000435', '2.938908']
# Fitting Solution:
# Output file saved as: Equation_4051.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4051.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001330', '-0.000544', '2.445889']
# Fitting Solution:
# Output file saved as: Equation_4052.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4052.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001301', '-0.000476', '2.733379']
# Fitting Solution:
# Output file saved as: Equation_4053.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4053.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001274', '-0.000426', '2.988053']
# Fitting Solution:
# Output file saved as: Equation_4054.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4054.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001278', '-0.000433', '2.950613']
# Fitting Solution:
# Output file saved as: Equation_4055.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4055.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001321', '-0.000519', '2.542277']
# Fitting Solution:
# Output file saved as: Equation_4056.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4056.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001339', '-0.000569', '2.353684']
# Fitting Solution:
# Output file saved as: Equation_4057.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4057.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001270', '-0.000420', '3.025358']
# Fitting Solution:
# Output file saved as: Equation_4058.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4058.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001323', '-0.000527', '2.512764']
# Fitting Solution:
# Output file saved as: Equation_4059.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4059.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001311', '-0.000498', '2.634424']
# Fitting Solution:
# Output file saved as: Equation_4060.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4060.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001312', '-0.000500', '2.623140']
# Fitting Solution:
# Output file saved as: Equation_4061.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4061.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001285', '-0.000446', '2.881398']
# Fitting Solution:
# Output file saved as: Equation_4062.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4062.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001299', '-0.000472', '2.751503']
# Fitting Solution:
# Output file saved as: Equation_4063.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4063.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001278', '-0.000433', '2.952643']
# Fitting Solution:
# Output file saved as: Equation_4064.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4064.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001300', '-0.000475', '2.737320']
# Fitting Solution:
# Output file saved as: Equation_4065.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4065.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001305', '-0.000484', '2.694756']
# Fitting Solution:
# Output file saved as: Equation_4066.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4066.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001271', '-0.000422', '3.011218']
# Fitting Solution:
# Output file saved as: Equation_4067.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4067.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001273', '-0.000425', '2.993168']
# Fitting Solution:
# Output file saved as: Equation_4068.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4068.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001287', '-0.000450', '2.861516']
# Fitting Solution:
# Output file saved as: Equation_4069.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4069.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001291', '-0.000457', '2.827787']
# Fitting Solution:
# Output file saved as: Equation_4070.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4070.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001312', '-0.000500', '2.624863']
# Fitting Solution:
# Output file saved as: Equation_4071.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4071.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001302', '-0.000478', '2.725617']
# Fitting Solution:
# Output file saved as: Equation_4072.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4072.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001285', '-0.000446', '2.880539']
# Fitting Solution:
# Output file saved as: Equation_4073.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4073.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001342', '-0.000580', '2.314648']
# Fitting Solution:
# Output file saved as: Equation_4074.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4074.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001321', '-0.000521', '2.537268']
# Fitting Solution:
# Output file saved as: Equation_4075.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4075.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001272', '-0.000424', '3.002608']
# Fitting Solution:
# Output file saved as: Equation_4076.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4076.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001300', '-0.000474', '2.744200']
# Fitting Solution:
# Output file saved as: Equation_4077.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4077.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001307', '-0.000489', '2.674713']
# Fitting Solution:
# Output file saved as: Equation_4078.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4078.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001298', '-0.000470', '2.760006']
# Fitting Solution:
# Output file saved as: Equation_4079.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4079.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001339', '-0.000572', '2.343165']
# Fitting Solution:
# Output file saved as: Equation_4080.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4080.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001292', '-0.000459', '2.816286']
# Fitting Solution:
# Output file saved as: Equation_4081.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4081.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001312', '-0.000499', '2.627776']
# Fitting Solution:
# Output file saved as: Equation_4082.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4082.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001321', '-0.000520', '2.538264']
# Fitting Solution:
# Output file saved as: Equation_4083.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4083.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001277', '-0.000431', '2.959830']
# Fitting Solution:
# Output file saved as: Equation_4084.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4084.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001276', '-0.000431', '2.964550']
# Fitting Solution:
# Output file saved as: Equation_4085.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4085.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001327', '-0.000537', '2.473247']
# Fitting Solution:
# Output file saved as: Equation_4086.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4086.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001266', '-0.000414', '3.058958']
# Fitting Solution:
# Output file saved as: Equation_4087.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4087.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001339', '-0.000571', '2.344090']
# Fitting Solution:
# Output file saved as: Equation_4088.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4088.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001296', '-0.000466', '2.781335']
# Fitting Solution:
# Output file saved as: Equation_4089.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4089.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001321', '-0.000520', '2.541193']
# Fitting Solution:
# Output file saved as: Equation_4090.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4090.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001280', '-0.000436', '2.932527']
# Fitting Solution:
# Output file saved as: Equation_4091.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4091.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001291', '-0.000457', '2.825814']
# Fitting Solution:
# Output file saved as: Equation_4092.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4092.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001299', '-0.000472', '2.750471']
# Fitting Solution:
# Output file saved as: Equation_4093.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4093.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001327', '-0.000536', '2.474121']
# Fitting Solution:
# Output file saved as: Equation_4094.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4094.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001286', '-0.000448', '2.870750']
# Fitting Solution:
# Output file saved as: Equation_4095.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4095.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001295', '-0.000465', '2.784542']
# Fitting Solution:
# Output file saved as: Equation_4096.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4096.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001269', '-0.000418', '3.032951']
# Fitting Solution:
# Output file saved as: Equation_4097.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4097.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001295', '-0.000464', '2.790461']
# Fitting Solution:
# Output file saved as: Equation_4098.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4098.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001291', '-0.000456', '2.831083']
# Fitting Solution:
# Output file saved as: Equation_4099.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4099.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001325', '-0.000531', '2.495914']
# Fitting Solution:
# Output file saved as: Equation_4100.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4100.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001281', '-0.000439', '2.918978']
# Fitting Solution:
# Output file saved as: Equation_4101.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4101.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001267', '-0.000416', '3.049010']
# Fitting Solution:
# Output file saved as: Equation_4102.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4102.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001304', '-0.000482', '2.704335']
# Fitting Solution:
# Output file saved as: Equation_4103.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4103.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001282', '-0.000440', '2.911394']
# Fitting Solution:
# Output file saved as: Equation_4104.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4104.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001317', '-0.000510', '2.582184']
# Fitting Solution:
# Output file saved as: Equation_4105.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4105.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001329', '-0.000540', '2.458477']
# Fitting Solution:
# Output file saved as: Equation_4106.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4106.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001273', '-0.000424', '2.999308']
# Fitting Solution:
# Output file saved as: Equation_4107.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4107.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001272', '-0.000424', '3.002141']
# Fitting Solution:
# Output file saved as: Equation_4108.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4108.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001331', '-0.000546', '2.436605']
# Fitting Solution:
# Output file saved as: Equation_4109.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4109.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001273', '-0.000424', '2.999411']
# Fitting Solution:
# Output file saved as: Equation_4110.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4110.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001305', '-0.000484', '2.694585']
# Fitting Solution:
# Output file saved as: Equation_4111.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4111.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001304', '-0.000483', '2.700766']
# Fitting Solution:
# Output file saved as: Equation_4112.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4112.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001268', '-0.000416', '3.045853']
# Fitting Solution:
# Output file saved as: Equation_4113.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4113.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001311', '-0.000498', '2.632912']
# Fitting Solution:
# Output file saved as: Equation_4114.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4114.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001336', '-0.000562', '2.379121']
# Fitting Solution:
# Output file saved as: Equation_4115.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4115.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001273', '-0.000424', '3.001071']
# Fitting Solution:
# Output file saved as: Equation_4116.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4116.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001277', '-0.000432', '2.957627']
# Fitting Solution:
# Output file saved as: Equation_4117.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4117.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001293', '-0.000461', '2.806133']
# Fitting Solution:
# Output file saved as: Equation_4118.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4118.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001272', '-0.000423', '3.006763']
# Fitting Solution:
# Output file saved as: Equation_4119.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4119.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001293', '-0.000460', '2.812378']
# Fitting Solution:
# Output file saved as: Equation_4120.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4120.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001308', '-0.000490', '2.668419']
# Fitting Solution:
# Output file saved as: Equation_4121.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4121.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001314', '-0.000504', '2.605158']
# Fitting Solution:
# Output file saved as: Equation_4122.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4122.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001282', '-0.000440', '2.914319']
# Fitting Solution:
# Output file saved as: Equation_4123.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4123.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001339', '-0.000569', '2.351587']
# Fitting Solution:
# Output file saved as: Equation_4124.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4124.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001306', '-0.000487', '2.680459']
# Fitting Solution:
# Output file saved as: Equation_4125.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4125.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001302', '-0.000478', '2.725892']
# Fitting Solution:
# Output file saved as: Equation_4126.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4126.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001291', '-0.000457', '2.826250']
# Fitting Solution:
# Output file saved as: Equation_4127.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4127.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001276', '-0.000431', '2.963623']
# Fitting Solution:
# Output file saved as: Equation_4128.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4128.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001277', '-0.000432', '2.954625']
# Fitting Solution:
# Output file saved as: Equation_4129.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4129.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001275', '-0.000428', '2.979569']
# Fitting Solution:
# Output file saved as: Equation_4130.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4130.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001271', '-0.000421', '3.018343']
# Fitting Solution:
# Output file saved as: Equation_4131.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4131.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001339', '-0.000571', '2.344133']
# Fitting Solution:
# Output file saved as: Equation_4132.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4132.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001282', '-0.000440', '2.911707']
# Fitting Solution:
# Output file saved as: Equation_4133.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4133.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001301', '-0.000477', '2.727490']
#
# Processing Batch 2/10
# IDs: 4134 to 4234
# Intercept: 8.8 (W/mK), y_end: 9.0 (W/mK)
#
# Starting process for equations 4134 to 4234
# Generated DataFrame shape: (10000, 5)
# Fitting Solution:
# Output file saved as: Equation_4134.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4134.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001306', '-0.000490', '2.664102']
# Fitting Solution:
# Output file saved as: Equation_4135.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4135.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001287', '-0.000452', '2.848423']
# Fitting Solution:
# Output file saved as: Equation_4136.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4136.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001277', '-0.000434', '2.944848']
# Fitting Solution:
# Output file saved as: Equation_4137.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4137.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001286', '-0.000450', '2.860077']
# Fitting Solution:
# Output file saved as: Equation_4138.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4138.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001285', '-0.000448', '2.869087']
# Fitting Solution:
# Output file saved as: Equation_4139.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4139.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001297', '-0.000472', '2.748880']
# Fitting Solution:
# Output file saved as: Equation_4140.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4140.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001285', '-0.000449', '2.865183']
# Fitting Solution:
# Output file saved as: Equation_4141.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4141.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001272', '-0.000425', '2.992602']
# Fitting Solution:
# Output file saved as: Equation_4142.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4142.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001278', '-0.000436', '2.931195']
# Fitting Solution:
# Output file saved as: Equation_4143.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4143.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001275', '-0.000432', '2.955581']
# Fitting Solution:
# Output file saved as: Equation_4144.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4144.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001311', '-0.000500', '2.622771']
# Fitting Solution:
# Output file saved as: Equation_4145.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4145.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001343', '-0.000586', '2.290773']
# Fitting Solution:
# Output file saved as: Equation_4146.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4146.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001327', '-0.000539', '2.460125']
# Fitting Solution:
# Output file saved as: Equation_4147.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4147.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001311', '-0.000500', '2.623747']
# Fitting Solution:
# Output file saved as: Equation_4148.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4148.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001348', '-0.000605', '2.226570']
# Fitting Solution:
# Output file saved as: Equation_4149.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4149.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001311', '-0.000501', '2.618833']
# Fitting Solution:
# Output file saved as: Equation_4150.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4150.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001288', '-0.000454', '2.836264']
# Fitting Solution:
# Output file saved as: Equation_4151.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4151.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001306', '-0.000489', '2.669214']
# Fitting Solution:
# Output file saved as: Equation_4152.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4152.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001322', '-0.000526', '2.514459']
# Fitting Solution:
# Output file saved as: Equation_4153.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4153.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001299', '-0.000474', '2.738380']
# Fitting Solution:
# Output file saved as: Equation_4154.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4154.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001275', '-0.000431', '2.955881']
# Fitting Solution:
# Output file saved as: Equation_4155.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4155.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001291', '-0.000459', '2.811318']
# Fitting Solution:
# Output file saved as: Equation_4156.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4156.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001284', '-0.000446', '2.879976']
# Fitting Solution:
# Output file saved as: Equation_4157.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4157.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001306', '-0.000490', '2.665464']
# Fitting Solution:
# Output file saved as: Equation_4158.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4158.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001288', '-0.000454', '2.835338']
# Fitting Solution:
# Output file saved as: Equation_4159.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4159.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001277', '-0.000434', '2.943730']
# Fitting Solution:
# Output file saved as: Equation_4160.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4160.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001306', '-0.000489', '2.669845']
# Fitting Solution:
# Output file saved as: Equation_4161.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4161.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001304', '-0.000484', '2.691447']
# Fitting Solution:
# Output file saved as: Equation_4162.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4162.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001323', '-0.000528', '2.504463']
# Fitting Solution:
# Output file saved as: Equation_4163.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4163.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001277', '-0.000434', '2.941564']
# Fitting Solution:
# Output file saved as: Equation_4164.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4164.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001314', '-0.000507', '2.591827']
# Fitting Solution:
# Output file saved as: Equation_4165.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4165.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001317', '-0.000514', '2.561203']
# Fitting Solution:
# Output file saved as: Equation_4166.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4166.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001320', '-0.000520', '2.536054']
# Fitting Solution:
# Output file saved as: Equation_4167.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4167.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001284', '-0.000446', '2.877406']
# Fitting Solution:
# Output file saved as: Equation_4168.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4168.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001280', '-0.000439', '2.914218']
# Fitting Solution:
# Output file saved as: Equation_4169.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4169.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001342', '-0.000584', '2.296557']
# Fitting Solution:
# Output file saved as: Equation_4170.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4170.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001330', '-0.000549', '2.425248']
# Fitting Solution:
# Output file saved as: Equation_4171.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4171.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001336', '-0.000565', '2.363713']
# Fitting Solution:
# Output file saved as: Equation_4172.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4172.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001341', '-0.000579', '2.314758']
# Fitting Solution:
# Output file saved as: Equation_4173.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4173.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001281', '-0.000440', '2.907525']
# Fitting Solution:
# Output file saved as: Equation_4174.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4174.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001316', '-0.000512', '2.569044']
# Fitting Solution:
# Output file saved as: Equation_4175.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4175.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001326', '-0.000538', '2.467619']
# Fitting Solution:
# Output file saved as: Equation_4176.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4176.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001319', '-0.000520', '2.539108']
# Fitting Solution:
# Output file saved as: Equation_4177.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4177.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001293', '-0.000464', '2.787779']
# Fitting Solution:
# Output file saved as: Equation_4178.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4178.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001306', '-0.000490', '2.665790']
# Fitting Solution:
# Output file saved as: Equation_4179.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4179.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001291', '-0.000460', '2.806579']
# Fitting Solution:
# Output file saved as: Equation_4180.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4180.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001284', '-0.000447', '2.872747']
# Fitting Solution:
# Output file saved as: Equation_4181.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4181.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001328', '-0.000543', '2.448092']
# Fitting Solution:
# Output file saved as: Equation_4182.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4182.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001328', '-0.000541', '2.455061']
# Fitting Solution:
# Output file saved as: Equation_4183.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4183.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001285', '-0.000448', '2.868854']
# Fitting Solution:
# Output file saved as: Equation_4184.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4184.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001278', '-0.000436', '2.930193']
# Fitting Solution:
# Output file saved as: Equation_4185.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4185.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001271', '-0.000424', '2.994841']
# Fitting Solution:
# Output file saved as: Equation_4186.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4186.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001290', '-0.000458', '2.817667']
# Fitting Solution:
# Output file saved as: Equation_4187.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4187.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001312', '-0.000502', '2.614622']
# Fitting Solution:
# Output file saved as: Equation_4188.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4188.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001325', '-0.000533', '2.484965']
# Fitting Solution:
# Output file saved as: Equation_4189.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4189.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001319', '-0.000519', '2.541509']
# Fitting Solution:
# Output file saved as: Equation_4190.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4190.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001348', '-0.000606', '2.225763']
# Fitting Solution:
# Output file saved as: Equation_4191.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4191.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001348', '-0.000604', '2.232180']
# Fitting Solution:
# Output file saved as: Equation_4192.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4192.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001317', '-0.000514', '2.561675']
# Fitting Solution:
# Output file saved as: Equation_4193.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4193.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001324', '-0.000530', '2.495823']
# Fitting Solution:
# Output file saved as: Equation_4194.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4194.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001293', '-0.000464', '2.787270']
# Fitting Solution:
# Output file saved as: Equation_4195.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4195.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001273', '-0.000427', '2.981104']
# Fitting Solution:
# Output file saved as: Equation_4196.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4196.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001288', '-0.000454', '2.838671']
# Fitting Solution:
# Output file saved as: Equation_4197.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4197.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001340', '-0.000578', '2.317249']
# Fitting Solution:
# Output file saved as: Equation_4198.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4198.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001304', '-0.000485', '2.690282']
# Fitting Solution:
# Output file saved as: Equation_4199.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4199.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001312', '-0.000503', '2.607971']
# Fitting Solution:
# Output file saved as: Equation_4200.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4200.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001310', '-0.000498', '2.630463']
# Fitting Solution:
# Output file saved as: Equation_4201.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4201.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001303', '-0.000482', '2.699944']
# Fitting Solution:
# Output file saved as: Equation_4202.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4202.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001270', '-0.000423', '3.005555']
# Fitting Solution:
# Output file saved as: Equation_4203.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4203.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001300', '-0.000477', '2.725147']
# Fitting Solution:
# Output file saved as: Equation_4204.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4204.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001285', '-0.000448', '2.868173']
# Fitting Solution:
# Output file saved as: Equation_4205.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4205.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001275', '-0.000432', '2.955263']
# Fitting Solution:
# Output file saved as: Equation_4206.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4206.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001298', '-0.000472', '2.748615']
# Fitting Solution:
# Output file saved as: Equation_4207.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4207.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001306', '-0.000490', '2.667883']
# Fitting Solution:
# Output file saved as: Equation_4208.txt
# Program Completed
# ...
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001349', '-0.001086', '1.242669']
# Fitting Solution:
# Output file saved as: Equation_4935.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4935.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001255', '-0.000848', '1.480488']
# Fitting Solution:
# Output file saved as: Equation_4936.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4936.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001248', '-0.000834', '1.495556']
# Fitting Solution:
# Output file saved as: Equation_4937.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4937.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001263', '-0.000863', '1.463985']
# Fitting Solution:
# Output file saved as: Equation_4938.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4938.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001342', '-0.001061', '1.265618']
# Fitting Solution:
# Output file saved as: Equation_4939.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4939.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001317', '-0.000982', '1.340372']
# Fitting Solution:
# Output file saved as: Equation_4940.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4940.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001337', '-0.001043', '1.282026']
# Fitting Solution:
# Output file saved as: Equation_4941.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4941.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001231', '-0.000806', '1.527179']
# Fitting Solution:
# Output file saved as: Equation_4942.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4942.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001262', '-0.000861', '1.466373']
# Fitting Solution:
# Output file saved as: Equation_4943.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4943.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001221', '-0.000790', '1.544537']
# Fitting Solution:
# Output file saved as: Equation_4944.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4944.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001342', '-0.001059', '1.267087']
# Fitting Solution:
# Output file saved as: Equation_4945.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4945.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001243', '-0.000826', '1.504640']
# Fitting Solution:
# Output file saved as: Equation_4946.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4946.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001325', '-0.001005', '1.317960']
# Fitting Solution:
# Output file saved as: Equation_4947.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4947.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001225', '-0.000796', '1.537925']
# Fitting Solution:
# Output file saved as: Equation_4948.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4948.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001359', '-0.001126', '1.206192']
# Fitting Solution:
# Output file saved as: Equation_4949.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4949.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001275', '-0.000885', '1.439986']
# Fitting Solution:
# Output file saved as: Equation_4950.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4950.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001321', '-0.000993', '1.330137']
# Fitting Solution:
# Output file saved as: Equation_4951.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4951.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001324', '-0.001004', '1.319691']
# Fitting Solution:
# Output file saved as: Equation_4952.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4952.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001378', '-0.001508', '0.913194']
# Fitting Solution:
# Output file saved as: Equation_4953.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4953.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001244', '-0.000828', '1.502203']
# Fitting Solution:
# Output file saved as: Equation_4954.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4954.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001256', '-0.000850', '1.478663']
# Fitting Solution:
# Output file saved as: Equation_4955.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4955.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001242', '-0.000825', '1.505659']
# Fitting Solution:
# Output file saved as: Equation_4956.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4956.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001248', '-0.000835', '1.494620']
# Fitting Solution:
# Output file saved as: Equation_4957.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4957.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001255', '-0.000847', '1.481021']
# Fitting Solution:
# Output file saved as: Equation_4958.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4958.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001293', '-0.000924', '1.399433']
# Fitting Solution:
# Output file saved as: Equation_4959.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4959.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001384', '-0.001408', '0.982966']
# Fitting Solution:
# Output file saved as: Equation_4960.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4960.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001314', '-0.000975', '1.347921']
# Fitting Solution:
# Output file saved as: Equation_4961.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4961.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001332', '-0.001025', '1.299213']
# Fitting Solution:
# Output file saved as: Equation_4962.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4962.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001375', '-0.001531', '0.897944']
# Fitting Solution:
# Output file saved as: Equation_4963.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4963.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001353', '-0.001101', '1.229109']
# Fitting Solution:
# Output file saved as: Equation_4964.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4964.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001303', '-0.001876', '0.694242']
# Fitting Solution:
# Output file saved as: Equation_4965.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4965.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001365', '-0.001157', '1.179935']
# Fitting Solution:
# Output file saved as: Equation_4966.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4966.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001344', '-0.001714', '0.783802']
# Fitting Solution:
# Output file saved as: Equation_4967.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4967.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001233', '-0.000809', '1.523208']
# Fitting Solution:
# Output file saved as: Equation_4968.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4968.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001237', '-0.000816', '1.515312']
# Fitting Solution:
# Output file saved as: Equation_4969.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4969.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001281', '-0.000898', '1.426584']
# Fitting Solution:
# Output file saved as: Equation_4970.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4970.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001282', '-0.000899', '1.425406']
# Fitting Solution:
# Output file saved as: Equation_4971.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4971.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001351', '-0.001094', '1.235423']
# Fitting Solution:
# Output file saved as: Equation_4972.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4972.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001334', '-0.001756', '0.759634']
# Fitting Solution:
# Output file saved as: Equation_4973.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4973.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001253', '-0.000844', '1.485223']
# Fitting Solution:
# Output file saved as: Equation_4974.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4974.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001235', '-0.000812', '1.519941']
# Fitting Solution:
# Output file saved as: Equation_4975.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4975.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001361', '-0.001140', '1.194638']
# Fitting Solution:
# Output file saved as: Equation_4976.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4976.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001263', '-0.000863', '1.463979']
# Fitting Solution:
# Output file saved as: Equation_4977.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4977.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001281', '-0.000898', '1.426522']
# Fitting Solution:
# Output file saved as: Equation_4978.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4978.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001249', '-0.000836', '1.493187']
# Fitting Solution:
# Output file saved as: Equation_4979.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4979.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001383', '-0.001437', '0.962275']
# Fitting Solution:
# Output file saved as: Equation_4980.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4980.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001291', '-0.000918', '1.405344']
# Fitting Solution:
# Output file saved as: Equation_4981.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4981.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001243', '-0.000827', '1.503449']
# Fitting Solution:
# Output file saved as: Equation_4982.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4982.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001257', '-0.000852', '1.476488']
# Fitting Solution:
# Output file saved as: Equation_4983.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4983.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001278', '-0.000892', '1.433222']
# Fitting Solution:
# Output file saved as: Equation_4984.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4984.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001299', '-0.000938', '1.385001']
# Fitting Solution:
# Output file saved as: Equation_4985.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4985.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001272', '-0.000879', '1.447248']
# Fitting Solution:
# Output file saved as: Equation_4986.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4986.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001288', '-0.000912', '1.412258']
# Fitting Solution:
# Output file saved as: Equation_4987.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4987.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001335', '-0.001035', '1.289840']
# Fitting Solution:
# Output file saved as: Equation_4988.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4988.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001357', '-0.001648', '0.823327']
# Fitting Solution:
# Output file saved as: Equation_4989.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4989.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001248', '-0.000834', '1.495322']
# Fitting Solution:
# Output file saved as: Equation_4990.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4990.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001358', '-0.001646', '0.825018']
# Fitting Solution:
# Output file saved as: Equation_4991.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4991.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001223', '-0.000793', '1.541298']
# Fitting Solution:
# Output file saved as: Equation_4992.txt
# Program Completed
# Reading file: /Users/shiveshjha/Downloads/TDTR_WITH_ML-MAIN/equation_generation/Equation_4992.txt
# Number of lines in file: 60
# Sample data point: ['100.000000', '0.001382', '-0.001304', '1.060404']
